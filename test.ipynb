# %%
from constraint import ScheduleConfig, ScheduleModel
from util import get_solution_df
import pandas as pd
pd.set_option("display.max_columns", None)  # 예: 200개까지
pd.set_option("display.width", 4000)


start_date = "20260104"
nurses = ["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"]
weekly_rest_days = {
    0: 1,
    1: 1,
    2: 2,
    3: 2,
    4: 3,
    5: 3,
    6: 4,
    7: 4,
    8: 5,
    9: 5
}


config = ScheduleConfig(cycle_days=28)
model = ScheduleModel(start_date=start_date, nurses=nurses, config=config)
model.initialize_model(weekly_rest_days)

solution = model.solve(time_limit_seconds=30)
res = get_solution_df(solution, nurses, start_date, config)
# Out:
# 스케줄링 모델 초기화 중...
# 모델 풀이 중...

# %%
res
# Out:
#   (01/04, 일) (01/05, 월) (01/06, 화) (01/07, 수) (01/08, 목) (01/09, 금) (01/10, 토) (01/11, 일) (01/12, 월) (01/13, 화) (01/14, 수) (01/15, 목) (01/16, 금) (01/17, 토) (01/18, 일) (01/19, 월) (01/20, 화) (01/21, 수) (01/22, 목) (01/23, 금) (01/24, 토) (01/25, 일) (01/26, 월) (01/27, 화) (01/28, 수) (01/29, 목) (01/30, 금) (01/31, 토)  OFF  D  E  N
# A          E         WR          D          E          E          E        OFF         WR          D          E          E        OFF          N          N          N        OFF        OFF          D          D          D         WR          N          N        OFF        OFF        OFF         WR          D   11  6  6  5
# B          E         WR          D          D          D          D        OFF         WR          D          D          E          N          N        OFF        OFF        OFF        OFF        OFF          E          E         WR          D          E          N          N          N         WR        OFF   11  7  5  5
# C          D          E         WR          N          N        OFF        OFF        OFF         WR          D          D          E          E          E         WR          E          N          N        OFF        OFF        OFF          D          D          N          N        OFF        OFF         WR   12  5  5  6
# D        OFF        OFF         WR          D          D          D          E          E         WR          N          N          N        OFF        OFF         WR          D          E          N          N        OFF        OFF        OFF          D          D          D          E          E         WR   11  7  5  5
# E          D          D          E         WR          N          N        OFF        OFF        OFF         WR          D          E        OFF        OFF          D         WR          D          E        OFF          E          E         WR        OFF          E          E          N          N          N   11  5  7  5
# F          N          N          N         WR        OFF        OFF          D          D          E         WR        OFF          D          E          E          E         WR          D          D        OFF          N          N         WR        OFF        OFF        OFF          E          N          N   11  5  5  7
# G          N          N        OFF        OFF         WR          E          E          E          E          E         WR        OFF        OFF        OFF        OFF          E         WR          E          N          N          N        OFF         WR          D          D          D          D          D   11  5  7  5
# H        OFF          D          E          E         WR          N          N          N        OFF        OFF         WR          D          D          N          N          N         WR        OFF          D          D          E          E         WR          E          E        OFF        OFF        OFF   11  5  6  6
# I        OFF        OFF        OFF        OFF          E         WR          D          D          N          N          N         WR        OFF          D          E          N          N         WR        OFF        OFF          D          E          E         WR        OFF          D          D          E   12  6  5  5
# J        OFF          E          N          N        OFF         WR          N          N          N        OFF        OFF         WR          D          D          D          D          E         WR          E        OFF          D          N          N         WR        OFF        OFF          E          E   11  5  5  7
